# %%
import cv2
import matplotlib.pyplot as plt

name = 'docker.png'
img = cv2.imread(name, cv2.IMREAD_UNCHANGED)
plt.imshow(img)

# %%
import numpy as np
mask = (img == 0)
new_img = mask * [255, 188, 94]

new_img = new_img.astype('uint8')
# a, b, c = new_img.shape
# for i in range(a):
#     for j in range(b):
#         if np.any(new_img[i, j] != [0]*4):
#             new_img[i, j] = [255, 188, 94, 255]
plt.imshow(new_img)

# %%
plt.imsave('assets/images/' + name, new_img)

# %%
a = np.ones((25,25, 4))
a = a * [255, 188, 94, 255]
a = a.astype('uint8')
plt.imshow(a)
